# %%
# %matplotlib inline
from brokenaxes import brokenaxes
import matplotlib.pyplot as plt
import numpy as np
import scipy.io as sci
from matplotlib.ticker import AutoMinorLocator
#PA group comparison
mat = sci.loadmat('emx-av.mat')

minor_locator = AutoMinorLocator(2)
minor_locatorx = AutoMinorLocator(2)

plt.rcParams['font.family'] = "Arial"
plt.rcParams.update({'font.size': 10})
plt.rcParams['savefig.bbox'] = 'tight'
plt.rcParams['lines.markersize'] = 4

bar_input = mat['bar_input']
ebars = mat['ebars']
x = [1,3,5,10,20,50,100,1000]
y1 = bar_input[0,:]
error1 = ebars[0,:]
y2 = bar_input[6,:]
error2 = ebars[6,:]

bax = brokenaxes(xlims=((-10, 109),(990, 1005)), wspace = 0.1)

bax.set_ylim(-3,30)
bax.plot(x, y1, '0.4')
bax.plot(x, y2, '0.4')
bax.plot(x[0:2],y1[0:2],'o',color = '0.4')
bax.plot(x[3:7],y1[3:7],'o',color = '0.4', label='Baseline')
bax.plot(x[0:2],y2[0:2],'o',color = '0.4')
bax.plot(x[3:7],y2[3:7],'o',color = '0.4', label='+7 Days')

bax.plot(x[2],y1[2],'ro')
bax.plot(x[2],y2[2],'ro')
bax.plot(x[7],y1[7],'ko')
bax.plot(x[7],y2[7],'ko')

bax.fill_between(x, y1-error1, y1+error1,facecolor='0.7')
bax.fill_between(x, y2-error2, y2+error2,facecolor='0.7')

bax.set_ylabel('Angle(\xb0)', labelpad = 25)
bax.set_xlabel('Stimulus Duration(ms)', labelpad = 25)

bax.axs[0].yaxis.set_minor_locator(minor_locator)
bax.axs[0].xaxis.set_minor_locator(minor_locatorx)
bax.tick_params(which='major', length=5)
bax.tick_params(which='minor', length=3)
bax.axs[0].set_yticks([0,10,20,30])
bax.axs[0].set_xticks([0,50,100])
fig = plt.gcf()

fig.set_size_inches(2,2)

fig.savefig('EMX baseline_day7_SEB.svg')

plt.show()

# %%
print(bar_input[0,:])
# Out:
# [  0.23770456   1.17364436   2.80481462   5.31960913   8.666182
#   13.51938332  14.20724357  14.41516409]

# %%
mat = sci.loadmat('emx-av_v.mat')

bar_input = mat['bar_input']
ebars = mat['ebars']
x = [1,3,5,10,20,50,100,1000]
y1 = bar_input[0,:]
error1 = ebars[0,:]
y2 = bar_input[6,:]
error2 = ebars[6,:]

bax = brokenaxes(xlims=((-10, 109),(990, 1005)), wspace = 0.1)
bax.set_ylim(-100,1200)
bax.plot(x, y1, '0.4')
bax.plot(x, y2, '0.4')
bax.plot(x[0:2],y1[0:2],'o',color = '0.4')
bax.plot(x[3:7],y1[3:7],'o',color = '0.4', label='Baseline')
bax.plot(x[0:2],y2[0:2],'o',color = '0.4')
bax.plot(x[3:7],y2[3:7],'o',color = '0.4', label='+7 Days')

bax.plot(x[2],y1[2],'ro')
bax.plot(x[2],y2[2],'ro')
base = bax.plot(x[7],y1[7],'ko')
seven = bax.plot(x[7],y2[7],'ko')


bax.fill_between(x, y1-error1, y1+error1,facecolor='0.7')
bax.fill_between(x, y2-error2, y2+error2,facecolor='0.7')

bax.set_ylabel('Velocity(\xb0/s)', labelpad = 30)
bax.set_xlabel('Stimulus Duration(ms)', labelpad = 25)


bax.axs[0].yaxis.set_minor_locator(minor_locator)
bax.axs[0].xaxis.set_minor_locator(minor_locatorx)
bax.tick_params(which='major', length=5)
bax.tick_params(which='minor', length=3)
bax.axs[0].set_yticks([0,400,800,1200])
bax.axs[0].set_xticks([0,50,100])
fig = plt.gcf()

fig.set_size_inches(2,2)

fig.savefig('EMX baseline_day7_SEB_PV.svg')

plt.show()

# %%
#PA group comparison
mat = sci.loadmat('emx-avr.mat')

bar_input = mat['bar_input']
ebars = mat['ebars']
x = [1,3,5,10,20,50,100,1000]
y1 = bar_input[0,:]
error1 = ebars[0,:]
y2 = bar_input[6,:]
error2 = ebars[6,:]


bax = brokenaxes(xlims=((-10, 109),(990, 1005)), wspace = 0.1)

bax.set_ylim(-20,3)
bax.plot(x, y1, '0.4')
bax.plot(x, y2, '0.4')
bax.plot(x[0:2],y1[0:2],'o',color = '0.4')
bax.plot(x[3:7],y1[3:7],'o',color = '0.4', label='Baseline')
bax.plot(x[0:2],y2[0:2],'o',color = '0.4')
bax.plot(x[3:7],y2[3:7],'o',color = '0.4', label='+7 Days')

bax.plot(x[2],y1[2],'ro')
bax.plot(x[2],y2[2],'ro')
bax.plot(x[7],y1[7],'ko')
bax.plot(x[7],y2[7],'ko')

bax.fill_between(x, y1-error1, y1+error1,facecolor='0.7')
bax.fill_between(x, y2-error2, y2+error2,facecolor='0.7')

bax.set_ylabel('Angle(\xb0)', labelpad = 25)
bax.set_xlabel('Stimulus Duration(ms)', labelpad = 25)

bax.axs[0].set_yticks([-20,-10,0])
bax.axs[0].set_xticks([0,50,100])
bax.axs[0].yaxis.set_minor_locator(minor_locator)
bax.axs[0].xaxis.set_minor_locator(minor_locatorx)
bax.tick_params(which='major', length=5)
bax.tick_params(which='minor', length=3)
fig = plt.gcf()

fig.set_size_inches(2,2)

fig.savefig('EMX baseline_day7_SEBr.svg')

plt.show()

# %%
mat = sci.loadmat('emx-av_vr.mat')

bar_input = mat['bar_input']
ebars = mat['ebars']
x = [1,3,5,10,20,50,100,1000]
y1 = bar_input[0,:]
error1 = ebars[0,:]
y2 = bar_input[6,:]
error2 = ebars[6,:]

bax = brokenaxes(xlims=((-10, 109),(990, 1005)), wspace = 0.1)
bax.set_ylim(-1000,100)
bax.plot(x, y1, '0.4')
bax.plot(x, y2, '0.4')
bax.plot(x[0:2],y1[0:2],'o',color = '0.4')
bax.plot(x[3:7],y1[3:7],'o',color = '0.4', label='Baseline')
bax.plot(x[0:2],y2[0:2],'o',color = '0.4')
bax.plot(x[3:7],y2[3:7],'o',color = '0.4', label='+7 Days')

bax.plot(x[2],y1[2],'ro')
bax.plot(x[2],y2[2],'ro')
base = bax.plot(x[7],y1[7],'ko')
seven = bax.plot(x[7],y2[7],'ko')

bax.fill_between(x, y1-error1, y1+error1,facecolor='0.7')
bax.fill_between(x, y2-error2, y2+error2,facecolor='0.7')

bax.set_ylabel('Velocity(\xb0/s)', labelpad = 40)
bax.set_xlabel('Stimulus Duration(ms)', labelpad = 25)

bax.axs[0].yaxis.set_minor_locator(minor_locator)
bax.axs[0].xaxis.set_minor_locator(minor_locatorx)
bax.tick_params(which='major', length=5)
bax.tick_params(which='minor', length=3)
bax.axs[0].set_yticks([-1000, -500, 0])
bax.axs[0].set_xticks([0,50,100])

fig = plt.gcf()

fig.set_size_inches(2,2)

fig.savefig('EMX baseline_day7_SEB_PVr.svg')

plt.show()

# %%
mat = sci.loadmat('acta-av.mat')

bar_input = mat['bar_input']
ebars = mat['ebars']
x = [1,3,5,10,20,50,100,1000]
y1 = bar_input[0,:]
error1 = ebars[0,:]
y2 = bar_input[6,:]
error2 = ebars[6,:]

bax = brokenaxes(xlims=((-10, 109),(990, 1005)), wspace = 0.1)

bax.set_ylim(-3,30)
bax.plot(x, y1, '0.4')
bax.plot(x, y2, '0.4')
bax.plot(x[0:2],y1[0:2],'o',color = '0.4')
bax.plot(x[3:7],y1[3:7],'o',color = '0.4', label='Baseline')
bax.plot(x[0:2],y2[0:2],'o',color = '0.4')
bax.plot(x[3:7],y2[3:7],'o',color = '0.4', label='+7 Days')

bax.plot(x[2],y1[2],'ro')
bax.plot(x[2],y2[2],'ro')
bax.plot(x[7],y1[7],'ko')
bax.plot(x[7],y2[7],'ko')

bax.fill_between(x, y1-error1, y1+error1,facecolor='0.7')
bax.fill_between(x, y2-error2, y2+error2,facecolor='0.7')

bax.set_ylabel('Angle(\xb0)', labelpad = 25)
bax.set_xlabel('Stimulus Duration(ms)', labelpad = 25)


bax.axs[0].yaxis.set_minor_locator(minor_locator)
bax.axs[0].xaxis.set_minor_locator(minor_locatorx)
bax.tick_params(which='major', length=5)
bax.tick_params(which='minor', length=3)
bax.axs[0].set_yticks([0,10,20,30])
bax.axs[0].set_xticks([0,50,100])
fig = plt.gcf()
fig.set_size_inches(2,2)

fig.savefig('ACTA baseline_day7_SEB.svg')

plt.show()

# %%
mat = sci.loadmat('acta-av_v.mat')

bar_input = mat['bar_input']
ebars = mat['ebars']
x = [1,3,5,10,20,50,100,1000]
y1 = bar_input[0,:]
error1 = ebars[0,:]
y2 = bar_input[6,:]
error2 = ebars[6,:]

bax = brokenaxes(xlims=((-10, 109),(990, 1005)), wspace = 0.1)
bax.set_ylim(-100,1200)
bax.plot(x, y1, '0.4')
bax.plot(x, y2, '0.4')
bax.plot(x[0:2],y1[0:2],'o',color = '0.4')
bax.plot(x[3:7],y1[3:7],'o',color = '0.4', label='Baseline')
bax.plot(x[0:2],y2[0:2],'o',color = '0.4')
bax.plot(x[3:7],y2[3:7],'o',color = '0.4', label='+7 Days')

bax.plot(x[2],y1[2],'ro')
bax.plot(x[2],y2[2],'ro')
base = bax.plot(x[7],y1[7],'ko')
seven = bax.plot(x[7],y2[7],'ko')


bax.fill_between(x, y1-error1, y1+error1,facecolor='0.7')
bax.fill_between(x, y2-error2, y2+error2,facecolor='0.7')

bax.set_ylabel('Velocity(\xb0/s)', labelpad = 25)
bax.set_xlabel('Stimulus Duration(ms)', labelpad = 25)


bax.axs[0].yaxis.set_minor_locator(minor_locator)
bax.axs[0].xaxis.set_minor_locator(minor_locatorx)
bax.tick_params(which='major', length=5)
bax.tick_params(which='minor', length=3)
bax.axs[0].set_yticks([0,400,800,1200])
bax.axs[0].set_xticks([0,50,100])
fig = plt.gcf()
fig.set_size_inches(2,2)

fig.savefig('ACTA baseline_day7_SEB_PV.svg')

plt.show()

# %%
mat = sci.loadmat('chat_av.mat')

bar_input = mat['bar_input']
x = [1,3,5,10,20,50,100,1000]
y1 = bar_input[0,:,0]
error1 = bar_input[0,:,1]
y2 = bar_input[2,:,0]
error2 = bar_input[2,:,1]

bax = brokenaxes(xlims=((-10, 109),(990, 1005)), wspace = 0.1)

bax.set_ylim(-1,12)
bax.plot(x, y1, '0.4')
bax.plot(x, y2, '0.4')
bax.plot(x[0:2],y1[0:2],'o',color = '0.4')
bax.plot(x[3:7],y1[3:7],'o',color = '0.4', label='Baseline')
bax.plot(x[0:2],y2[0:2],'o',color = '0.4')
bax.plot(x[3:7],y2[3:7],'o',color = '0.4', label='+7 Days')

bax.plot(x[2],y1[2],'ro')
bax.plot(x[2],y2[2],'ro')
bax.plot(x[7],y1[7],'ko')
bax.plot(x[7],y2[7],'ko')

bax.fill_between(x, y1-error1, y1+error1,facecolor='0.7')
bax.fill_between(x, y2-error2, y2+error2,facecolor='0.7')

bax.set_ylabel('Angle(\xb0)', labelpad = 25)
bax.set_xlabel('Stimulus Duration(ms)', labelpad = 25)


bax.axs[0].yaxis.set_minor_locator(minor_locator)
bax.axs[0].xaxis.set_minor_locator(minor_locatorx)
bax.tick_params(which='major', length=5)
bax.tick_params(which='minor', length=3)
bax.axs[0].set_yticks([0,4,8,12])
bax.axs[0].set_xticks([0,50,100])
fig = plt.gcf()
fig.set_size_inches(2,2)
fig.savefig('CHAT baseline_6hr_SEB.svg')

plt.show()

# %%
mat = sci.loadmat('chat_av_v.mat')

bar_input = mat['bar_input']
x = [1,3,5,10,20,50,100,1000]
y1 = bar_input[0,:,0]
error1 = bar_input[0,:,1]
y2 = bar_input[2,:,0]
error2 = bar_input[2,:,1]

bax = brokenaxes(xlims=((-10, 109),(990, 1005)), wspace = 0.1)
bax.set_ylim(-100,1200)
bax.plot(x, y1, '0.4')
bax.plot(x, y2, '0.4')
bax.plot(x[0:2],y1[0:2],'o',color = '0.4')
bax.plot(x[3:7],y1[3:7],'o',color = '0.4', label='Baseline')
bax.plot(x[0:2],y2[0:2],'o',color = '0.4')
bax.plot(x[3:7],y2[3:7],'o',color = '0.4', label='+7 Days')

bax.plot(x[2],y1[2],'ro')
bax.plot(x[2],y2[2],'ro')
base = bax.plot(x[7],y1[7],'ko')
seven = bax.plot(x[7],y2[7],'ko')


bax.fill_between(x, y1-error1, y1+error1,facecolor='0.7')
bax.fill_between(x, y2-error2, y2+error2,facecolor='0.7')

bax.set_ylabel('Velocity(\xb0/s)', labelpad = 25)
bax.set_xlabel('Stimulus Duration(ms)', labelpad = 25)


bax.axs[0].yaxis.set_minor_locator(minor_locator)
bax.axs[0].xaxis.set_minor_locator(minor_locatorx)
bax.tick_params(which='major', length=5)
bax.tick_params(which='minor', length=3)
bax.axs[0].set_yticks([0,400,800,1200])
bax.axs[0].set_xticks([0,50,100])
fig = plt.gcf()

fig.set_size_inches(2,2)
fig.savefig('CHAT baseline_6hr_SEB_PV.svg')

plt.show()

# %%
mat = sci.loadmat('emx-av.mat')

bar_input = mat['bar_input']
ebars = mat['ebars']
x = [-2,0,1,2,3,4,7,8,9,10]
y1 = bar_input[:,2]
error1 = ebars[:,2]
y2 = bar_input[:,7]
error2 = ebars[:,7]


fig, bax = plt.subplots()
bax.plot(x, y1,'ro-')
bax.fill_between(x, y1-error1, y1+error1,facecolor='0.7')
bax.plot(x, y2,'ko-')
bax.fill_between(x, y2-error2, y2+error2,facecolor='0.7')
bax.vlines(0,-3,30,color = 'k', linestyles = 'dashed')
bax.set_ylabel('Angle(\xb0)')
bax.set_xlabel('Days After Lesion')
bax.set_ylim(-3,30)
bax.tick_params(which='major', length=5)
bax.tick_params(which='minor', length=3)
plt.xticks([-2,0,2,4,6,8,10],('Pre','0','2','4','6','8','10'))
bax.set_yticks([0,10,20,30])
bax.yaxis.set_minor_locator(minor_locator)
bax.xaxis.set_minor_locator(minor_locatorx)
plt.tick_params(which='major', length=5)
plt.tick_params(which='minor', length=3)
bax.spines['top'].set_visible(False)
bax.spines['right'].set_visible(False)
plt.gcf().set_size_inches(2,2)


#ax.set_title('EMX 5,1000ms Stimuli Over Days')
plt.savefig('EMX-Stimuli_OverDays.svg')
plt.show()

# %%
print(bar_input[0,:])
# Out:
# [  0.23770456   1.17364436   2.80481462   5.31960913   8.666182
#   13.51938332  14.20724357  14.41516409]

# %%
mat = sci.loadmat('emx-avr.mat')

bar_input = mat['bar_input']
ebars = mat['ebars']
x = [-2,0,1,2,3,4,7,8,9,10]
y1 = bar_input[:,2]
error1 = ebars[:,2]
y2 = bar_input[:,7]
error2 = ebars[:,7]


fig, bax = plt.subplots()
bax.plot(x, y1,'ro-')
bax.fill_between(x, y1-error1, y1+error1,facecolor='0.7')
bax.plot(x, y2,'ko-')
bax.fill_between(x, y2-error2, y2+error2,facecolor='0.7')
bax.vlines(0,-20,3,color = 'k', linestyles = 'dashed')
bax.set_ylim(-20,3)
bax.set_xlim(-3,-1)
plt.xticks([-2,0,2,4,6,8,10],('Pre','0','2','4','6','8','10'))
bax.set_yticks([-20,-10,0])
bax.yaxis.set_minor_locator(minor_locator)
bax.xaxis.set_minor_locator(minor_locatorx)
plt.tick_params(which='major', length=5)
plt.tick_params(which='minor', length=3)
bax.spines['top'].set_visible(False)
bax.spines['right'].set_visible(False)
bax.set_ylabel('Angle(\xb0)')
bax.set_xlabel('Days After Lesion')
bax.set_ylim(-20,3)
fig = plt.gcf()
fig.set_size_inches(2,2)


#ax.set_title('EMX 5,1000ms Stimuli Over Days')
plt.savefig('EMX-Stimuli_OverDaysr.svg')
plt.show()

# %%
mat = sci.loadmat('emx-av_v.mat')

bar_input = mat['bar_input']
ebars = mat['ebars']
x = [-2,0,1,2,3,4,7,8,9,10]
y1 = bar_input[:,2]
error1 = ebars[:,2]
y2 = bar_input[:,7]
error2 = ebars[:,7]


fig, bax = plt.subplots()
bax.plot(x, y1,'ro-')
bax.fill_between(x, y1-error1, y1+error1,facecolor='0.7')
bax.plot(x, y2,'ko-')
bax.fill_between(x, y2-error2, y2+error2,facecolor='0.7')
plt.xticks([-2,0,2,4,6,8,10],('Pre','0','2','4','6','8','10'))
#bax.set_xticks([0,2,4,6,8,10])
bax.set_ylabel('Velocity(\xb0/s)')
bax.set_xlabel('Days After Lesion')
bax.vlines(0,-100,1200,color = 'k', linestyles = 'dashed')
bax.set_ylim(-100,1200)
bax.yaxis.set_minor_locator(minor_locator)
bax.xaxis.set_minor_locator(minor_locatorx)
plt.tick_params(which='major', length=5)
plt.tick_params(which='minor', length=3)
bax.set_yticks([0,400,800,1200])
bax.spines['top'].set_visible(False)
bax.spines['right'].set_visible(False)
fig = plt.gcf()
fig.set_size_inches(2,2)

#ax.set_title('EMX 5,1000ms Stimuli Over Days')
plt.savefig('EMX-Stimuli_OverDays_PV.svg')
plt.show()

# %%
mat = sci.loadmat('emx-av_vr.mat')

bar_input = mat['bar_input']
ebars = mat['ebars']
x = [-2,0,1,2,3,4,7,8,9,10]
y1 = bar_input[:,2]
error1 = ebars[:,2]
y2 = bar_input[:,7]
error2 = ebars[:,7]


fig, bax = plt.subplots()
bax.plot(x, y1,'ro-')
bax.fill_between(x, y1-error1, y1+error1,facecolor='0.7')
bax.plot(x, y2,'ko-')
bax.fill_between(x, y2-error2, y2+error2,facecolor='0.7')
bax.vlines(0,-1000,100,color = 'k', linestyles = 'dashed')
bax.set_ylim(-20,3)
bax.set_xlim(-3,-1)
plt.xticks([-2,0,2,4,6,8,10],('Pre','0','2','4','6','8','10'))
bax.set_yticks([-1000,-500,0])
bax.set_ylabel('Velocity(\xb0/s)')
bax.set_xlabel('Days After Lesion')
bax.set_ylim(-1000,100)
bax.yaxis.set_minor_locator(minor_locator)
bax.xaxis.set_minor_locator(minor_locatorx)
plt.tick_params(which='major', length=5)
plt.tick_params(which='minor', length=3)
bax.spines['top'].set_visible(False)
bax.spines['right'].set_visible(False)
fig = plt.gcf()
fig.set_size_inches(2,2)
#ax.set_title('EMX 5,1000ms Stimuli Over Days')
plt.savefig('EMX-Stimuli_OverDays_PVr.svg')
plt.show()

# %%
mat = sci.loadmat('acta-av.mat')

bar_input = mat['bar_input']
ebars = mat['ebars']
x = [-2,0,1,2,3,4,7,8,9,10]
y1 = bar_input[:,2]
error1 = ebars[:,2]
y2 = bar_input[:,7]
error2 = ebars[:,7]


fig, bax = plt.subplots()
bax.plot(x, y1,'ro-')
bax.fill_between(x, y1-error1, y1+error1,facecolor='0.7')
bax.plot(x, y2,'ko-')
bax.fill_between(x, y2-error2, y2+error2,facecolor='0.7')
bax.vlines(0,-3,30,color = 'k', linestyles = 'dashed')
bax.set_ylabel('Angle(\xb0)')
bax.set_xlabel('Days After Lesion',labelpad = 20)
bax.set_ylim(-3,30)
plt.xticks([-2,0,2,4,6,8,10],('Pre','0','2','4','6','8','10'))
bax.yaxis.set_minor_locator(minor_locator)
bax.xaxis.set_minor_locator(minor_locatorx)
plt.tick_params(which='major', length=5)
plt.tick_params(which='minor', length=3)
bax.spines['top'].set_visible(False)
bax.spines['right'].set_visible(False)
plt.gcf().set_size_inches(2,2)

bax.set_ylim(-3,30)
fig = plt.gcf()
fig.set_size_inches(2,2)
plt.savefig('ACTA-Stimuli_OverDays.svg')
plt.show()

# %%
mat = sci.loadmat('acta-av_v.mat')

bar_input = mat['bar_input']
ebars = mat['ebars']
x = [-2,0,1,2,3,4,7,8,9,10]
y1 = bar_input[:,2]
error1 = ebars[:,2]
y2 = bar_input[:,7]
error2 = ebars[:,7]



fig, bax = plt.subplots()
bax.plot(x, y1,'ro-')
bax.fill_between(x, y1-error1, y1+error1,facecolor='0.7')
bax.plot(x, y2,'ko-')
bax.fill_between(x, y2-error2, y2+error2,facecolor='0.7')
plt.xticks([-2,0,2,4,6,8,10],('Pre','0','2','4','6','8','10'))
bax.set_ylabel('Velocity(\xb0/s)')
bax.set_xlabel('Days After Lesion')
bax.vlines(0,-100,1200,color = 'k', linestyles = 'dashed')
bax.set_ylim(-100,1200)
bax.yaxis.set_minor_locator(minor_locator)
bax.xaxis.set_minor_locator(minor_locatorx)
plt.tick_params(which='major', length=5)
plt.tick_params(which='minor', length=3)
bax.spines['top'].set_visible(False)
bax.spines['right'].set_visible(False)
bax.set_yticks([0,400,800,1200])
fig = plt.gcf()
fig.set_size_inches(2,2)

#ax.set_title('EMX 5,1000ms Stimuli Over Days')
plt.savefig('ACTA-Stimuli_OverDays_PV.svg')
plt.show()

# %%
mat = sci.loadmat('chat_av.mat')

bar_input = mat['bar_input']

x = [-1,0,1,2]
y1 = bar_input[:,2,0]
error1 = bar_input[:,2,1]
y2 = bar_input[:,7,0]
error2 = bar_input[:,7,1]

ax = plt.subplot()
ax.plot(x, y1,color='r')
ax.plot(x, y1,'ro')
plt.fill_between(x, y1-error1, y1+error1,facecolor='0.7')
ax.plot(x, y2,color='k')
ax.plot(x, y2,'ko')
ax.vlines(0,-1,15,color = 'k', linestyles = 'dashed')
plt.fill_between(x, y2-error2, y2+error2,facecolor='0.7')
ax.set_ylabel('Angle(\xb0)')
ax.set_xlabel('Hours After Lesion')

plt.xticks([-1,0,1,2],('Pre','0.5h','6h','24h'))
plt.yticks([0,5,10,15,20,25,30])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
#ax.spines['bottom'].set_linewidth(1)
#ax.spines['left'].set_linewidth(1)
ax.yaxis.set_minor_locator(minor_locator)
ax.tick_params(which='major', length=5)
ax.tick_params(which='minor', length=3)
ax.set_ylim(-1,15)
#ax.set_xlim(-2,4)
fig = plt.gcf()
fig.set_size_inches(2,2)


#ax.set_title('EMX 5,1000ms Stimuli Over Days')
plt.savefig('CHAT-Stimuli_OverDays.svg')
plt.show()

# %%
mat = sci.loadmat('chat_av_v.mat')

bar_input = mat['bar_input']

x = [-1,0,1,2]
y1 = bar_input[:,2,0]
error1 = bar_input[:,2,1]
y2 = bar_input[:,7,0]
error2 = bar_input[:,7,1]

ax = plt.subplot()
ax.plot(x, y1,color='r')
ax.plot(x, y1,'ro')
plt.fill_between(x, y1-error1, y1+error1,facecolor='0.7')
ax.plot(x, y2,color='k')
ax.plot(x, y2,'ko')
ax.vlines(0,-100,1200,color = 'k', linestyles = 'dashed')
plt.fill_between(x, y2-error2, y2+error2,facecolor='0.7')
ax.set_ylabel('Velocity(\xb0/s)')
ax.set_xlabel('Hours After Lesion')
plt.xticks([-1,0,1,2],('Pre','0.5h','6h','24h'))
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
#ax.spines['bottom'].set_linewidth(1)
#ax.spines['left'].set_linewidth(1)
ax.yaxis.set_minor_locator(minor_locator)
plt.tick_params(which='major', length=5)
plt.tick_params(which='minor', length=3)
plt.yticks([0,400,800,1200])
ax.set_ylim(-100,1200)
#ax.set_xlim(-2,4)
fig = plt.gcf()
fig.set_size_inches(2,2)


#ax.set_title('EMX 5,1000ms Stimuli Over Days')
plt.savefig('CHAT-Stimuli_OverDays_PV.svg')
plt.show()

# %%
plt.rcParams['lines.markersize'] = 8

mat = sci.loadmat('chat_ttp.mat')
mat2 = sci.loadmat('chat_hw.mat')
bar_input = mat['bar_input']
bar_input2 = mat2['bar_input']
x = [1,3,5,10,20,50,100,1000]
y1 = bar_input[0,:,0]
error1 = bar_input[0,:,1]
y2 = bar_input2[0,:,0]
error2 = bar_input2[0,:,1]

bax = brokenaxes(xlims=((-10, 109),(990, 1005)), wspace = 0.1)

bax.set_ylim(-3,30)
bax.plot(x, y1, '0.4')
bax.plot(x, y2, '0.4')
bax.plot(x[0:2],y1[0:2],'^',color = '0.4')
bax.plot(x[3:7],y1[3:7],'^',color = '0.4', label='Baseline')
bax.plot(x[0:2],y2[0:2],'x',color = '0.4')
bax.plot(x[3:7],y2[3:7],'x',color = '0.4', label='+7 Days')

bax.plot(x[2],y1[2],'r^')
bax.plot(x[2],y2[2],'rx')
bax.plot(x[7],y1[7],'k^')
bax.plot(x[7],y2[7],'k^')

bax.fill_between(x, y1-error1, y1+error1,facecolor='0.7')
bax.fill_between(x, y2-error2, y2+error2,facecolor='0.7')

bax.set_ylabel('Time(ms)', labelpad = 25)
bax.set_xlabel('Stimulus Duration(ms)', labelpad = 25)


bax.axs[0].yaxis.set_minor_locator(minor_locator)
bax.axs[0].xaxis.set_minor_locator(minor_locatorx)
bax.tick_params(which='major', length=5)
bax.tick_params(which='minor', length=3)
bax.axs[0].set_yticks([0,10,20,30])
bax.axs[0].set_xticks([0,50,100])
fig = plt.gcf()

fig = plt.gcf()

fig.set_size_inches(2,2)
fig.savefig('CHAT baseline_ttpandhw.svg')

plt.show()

# %%
mat = sci.loadmat('chat_ttp.mat')
mat2 = sci.loadmat('chat_hw.mat')
bar_input = mat['bar_input']
bar_input2 = mat2['bar_input']

x = [-1,0,1,2]
y1 = bar_input[0:3,7,0]
error1 = bar_input[0:3,7,1]
y2 = bar_input2[0:3,7,0]
error2 = bar_input2[0:3,7,1]
y1 = np.append(y1, 0)
y2 = np.append(y2, 0)
error1 = np.append(error1, 0)
error2 = np.append(error2, 0)


ax = plt.subplot()
ax.plot(x, y1,color='k')
ax.plot(x, y1,'k^', label = 'Time to Peak')
plt.fill_between(x, y1-error1, y1+error1,facecolor='0.7')
ax.plot(x, y2,color='k')
ax.plot(x, y2,'kx', label = 'Half-Width')
ax.vlines(0,-4,31,color = 'k', linestyles = 'dashed')
plt.fill_between(x, y2-error2, y2+error2,facecolor='0.7')
ax.set_ylabel('Time(ms)')
ax.set_xlabel('Hours After Lesion')
plt.xticks([-1,0,1,2],('Pre','0.5h','6h','24h'))
plt.yticks([0,10,20,30])
ax.yaxis.set_minor_locator(minor_locator)
plt.tick_params(which='major', length=5)
plt.tick_params(which='minor', length=3)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
#ax.spines['bottom'].set_linewidth(1)
#ax.spines['left'].set_linewidth(1)
ax.set_ylim(-3,30)
ax.legend(fontsize = 9)
#ax.set_xlim(-2,4)
fig = plt.gcf()
fig.set_size_inches(2,2)


#ax.set_title('EMX 5,1000ms Stimuli Over Days')
plt.savefig('CHAT-ttpandhw_OverDays.svg')
plt.show()
